# %% [markdown]
# <a href="https://colab.research.google.com/github/Caioba123/Aula-Phyton/blob/main/04/11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Questão 1

# %%
def checar_semaforo(cor):
    if cor.lower() == "verde":
        return "Siga!"
    elif cor.lower() == "amarelo":
        return "Atenção!"
    elif cor.lower() == "vermelho":
        return "Pare!"
    else:
        return "Cor inválida."

# %% [markdown]
# Questão 2

# %%
def classificar_imc(imc):
    if imc < 18.5:
        return "Abaixo do peso"
    elif 18.5 <= imc < 24.9:
        return "Peso normal"
    elif 25.0 <= imc < 29.9:
        return "Sobrepeso"
    else:
        return "Obesidade"

# %% [markdown]
# Questão 3

# %%
def checar_elegibilidade(renda, score):
    if renda >= 5000 and score >= 700:
        return "Cartão Premium Elegível"
    elif renda >= 2000 and score >= 600:
        return "Cartão Standard Elegível"
    else:
        return "Não elegível no momento"

# %% [markdown]
# Questão 4

# %%
def sugerir_roupa(temp):
    if temp > 30:
        return "Muito calor! Use roupas leves. ☀️"
    elif 18 <= temp <= 30:
        return "Clima agradável. Uma camiseta e calça são ideais. 👕"
    else:
        return "Está frio. Vista um casaco! 🧥"

# %% [markdown]
# Questão 5

# %%
def verificar_vencedor(placar_time_a, placar_time_b):
    if placar_time_a > placar_time_b:
        return "Time A Venceu!"
    elif placar_time_b > placar_time_a:
        return "Time B Venceu!"
    else:
        return "Empate!"

# %% [markdown]
# Questão 6

# %%
def tipo_de_dia(dia_da_semana):
    dia = dia_da_semana.lower()
    if dia == "sábado" or dia == "sabado" or dia == "domingo":
        return "Fim de Semana! 🎉"
    else:
        return "Dia Útil. 💼"

# %% [markdown]
# Questão 7

# %%
def calcular_frete(valor_pedido):
    if valor_pedido >= 80:
        return valor_pedido  # frete grátis
    else:
        return valor_pedido + 10  # frete fixo

# %% [markdown]
# Questão 8

# %%
def classificar_avaliacao(estrelas):
    if estrelas == 5:
        return "Excelente!"
    elif estrelas == 4:
        return "Muito Bom."
    elif estrelas == 3:
        return "Satisfatório."
    elif estrelas == 2 or estrelas == 1:
        return "Insatisfatório."
    else:
        return "Avaliação Inválida."

# %% [markdown]
# Questão 9

# %%
def identificar_veiculo(placa):
    inicial = placa[0].upper()
    if inicial in ['A', 'B', 'C']:
        return "Carro de Passeio"
    elif inicial in ['M', 'N', 'O']:
        return "Motocicleta"
    else:
        return "Outro Tipo de Veículo"
